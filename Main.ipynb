# %%
from tkinter import *
from PIL import ImageTk,ImageDraw
from tkinter import ttk, messagebox
import pymysql
class main:
    def __init__(self,root):
        self.root=root
        self.root.title("Main")
        self.root.geometry ("1350x700+0+0")
        self.root.config(bg='black')
        self.root.iconbitmap('E:\Jupyter_Codes\project\icon.ico')
        #==Bg Image===
        
        self.bg=ImageTk.PhotoImage(file="Images/low.jpg")
        bg=Label(self.root,image=self.bg).place(x=0,y=0,width=1500)
        #==Left Image===
        
        self.left=ImageTk.PhotoImage(file="Images/project.png")
        left=Label(self.root,image=self.left).place(x=350,y=75,width=650,height=100)
        #==Login Frame==
        
        frame1=Frame(self.root,bg='white')
        frame1.place(x=350,y=175,width=650,height=438)
        
        title=Label(frame1, text="Admin",font=('times new roman',30,'bold'),bg='white',fg='black').place(x=280,y=20)
        
        
        btn_admin=Button(frame1, text="Monitor  ",font=('times new roman',18,),command=self.Face,justify=CENTER,cursor='hand2',bg='red',bd='1',fg='black').place(x=290,y=125)
        btn_admin=Button(frame1, text="Students ",font=('times new roman',18,),command=self.student,justify=CENTER,cursor='hand2',bg='red',bd='1',fg='black').place(x=290,y=175)
        btn_admin=Button(frame1, text="Teachers",font=('times new roman',18,),command=self.teacher,justify=CENTER,cursor='hand2',bg='red',bd='1',fg='black').place(x=290,y=225)
    def Face(self):
        self.root.destroy()
        # %run Face.ipynb
    def student(self):
        self.root.destroy()
        # %run student.ipynb
    def teacher(self):
        self.root.destroy()
        # %run teachers.ipynb
        
        
root=Tk()
obj=main(root)
root.mainloop()
# Out:
# ['Bill.jpg', 'Elon Musk.jpg', 'Elon Test.jpg', 'fahim.jpg', 'Nadim Reza.jpg', 'Niloy.jpg', 'Tamzid.jpg']
# ['Bill', 'Elon Musk', 'Elon Test', 'fahim', 'Nadim Reza', 'Niloy', 'Tamzid']
# Encoding Complete
# [0.80135346 0.81155053 0.81174583 0.41428769 0.61703843 0.68881757
#  0.64964255]
# FAHIM
# [0.80352261 0.88298386 0.90290916 0.38568476 0.69708471 0.72844327
#  0.54611665]
# FAHIM
# [0.79154821 0.84685778 0.85940691 0.36150562 0.6572657  0.68594454
#  0.56129246]
# FAHIM
# [0.76212273 0.85842687 0.86203318 0.35969534 0.7037139  0.71672985
#  0.56493304]
# FAHIM
# [0.79097348 0.87329886 0.883112   0.3302374  0.65682471 0.6869029
#  0.56334141]
# FAHIM
# [0.78342581 0.89355265 0.88640627 0.33666021 0.67559552 0.71514366
#  0.57037939]
# FAHIM
# [0.78090264 0.84952236 0.85690977 0.33305531 0.65910757 0.68066231
#  0.53634394]
# FAHIM
# [0.76821474 0.87036056 0.8810781  0.33448708 0.70137708 0.72702276
#  0.56661638]
# FAHIM
# ...
