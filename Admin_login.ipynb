# %%
from tkinter import *
from PIL import ImageTk,ImageDraw
from tkinter import ttk, messagebox
import pymysql
class login:
    def __init__(self,root):
        self.root=root
        self.root.title("Login Window")
        self.root.geometry ("1350x700+0+0")
        self.root.config(bg='black')
        self.root.iconbitmap('E:\Jupyter_Codes\project\icon.ico')
        #==Bg Image===
        
        self.bg=ImageTk.PhotoImage(file="Images/low.jpg")
        bg=Label(self.root,image=self.bg).place(x=0,y=0,width=1500)
        #==Left Image===
        
        self.left=ImageTk.PhotoImage(file="Images/project.png")
        left=Label(self.root,image=self.left).place(x=200,y=150,width=500,height=438)
        
        #==Login Frame==
        
        frame1=Frame(self.root,bg='white')
        frame1.place(x=700,y=150,width=500,height=438)
        
        title=Label(frame1, text="Admin Login",font=('times new roman',30,'bold'),bg='white',fg='blue').place(x=130,y=30)
        
        email=Label(frame1, text="Email",font=('times new roman',20,'bold'),bg='white',fg='grey').place(x=130,y=130)
        self.txt_email=Entry(frame1,font=('times new roman',14,),bg='lightgray')
        self.txt_email.place(x=130,y=170,width=300,height=30)
        
        password=Label(frame1, text="Password",font=('times new roman',20,'bold'),bg='white',fg='grey').place(x=130,y=230)
        self.txt_password=Entry(frame1,font=('times new roman',14,),bg='lightgray',show='*')
        self.txt_password.place(x=130,y=270,width=300,height=30)
        
        btn_reg=Button(frame1, text="Register New Account?",font=('times new roman',12,),cursor='hand2',command=self.register_window,bg='white',bd='0',fg='black').place(x=140,y=310)
        
        self.btn_img=ImageTk.PhotoImage(file='Images/lg2.png')
        btn_register=Button(frame1,image=self.btn_img,bd=0,cursor='hand2',command=self.login).place(x=130,y=350)
        

    def register_window(self):
        messagebox.showinfo("Warning","You need Administrative Authorization to Login as Admin.",parent=self.root)
    
    
    
    def login(self):
        if self.txt_email.get()=="" or self.txt_password.get()=="":
            messagebox.showerror("Error","All Fields Are Required!",parent=self.root)
        else:
            try:
                con = pymysql.connect(host='localhost',user='root',password='',database='project')
                cur=con.cursor()
                cur.execute('select * from admin where email=%s and password=%s',(self.txt_email.get(),self.txt_password.get()))
                row=cur.fetchone()
                #print(row)
                if row== None:
                    messagebox.showerror("Error","Invalid Email & Password",parent=self.root)
                    
                else:
                    
                    messagebox.showinfo("Success","Welcome",parent=self.root)
                    self.root.destroy()
                    # %run Main.ipynb   
                con.close()   
      
                
            except Exception as es:
                messagebox.showerror("Error",f"Error due to: {str(es)}",parent=self.root)
        
        
        
        
        
        
root=Tk()
obj=login(root)
root.mainloop()
# Out:
# ['Bill.jpg', 'Elon Musk.jpg', 'Elon Test.jpg', 'fahim.jpg', 'Nadim Reza.jpg', 'Niloy.jpg', 'Tamzid.jpg']
# ['Bill', 'Elon Musk', 'Elon Test', 'fahim', 'Nadim Reza', 'Niloy', 'Tamzid']
# Encoding Complete
# [0.79651359 0.82524896 0.84126727 0.32562748 0.6066954  0.65655256
#  0.5271194 ]
# FAHIM
# [0.78391685 0.80897294 0.83332328 0.40180593 0.6331383  0.64756803
#  0.51706834]
# FAHIM
# [0.81742831 0.77645143 0.79798353 0.42989238 0.63160278 0.70962684
#  0.48716323]
# FAHIM
# [0.79536503 0.82803643 0.84781101 0.36008963 0.63874295 0.68860269
#  0.52159817]
# FAHIM
# [0.79523073 0.8127919  0.83529345 0.37150775 0.64031535 0.66615949
#  0.52669382]
# FAHIM
# [0.78705359 0.81481536 0.83249997 0.35470707 0.62278523 0.6727636
#  0.54124208]
# FAHIM
# [0.79452666 0.80370262 0.83626852 0.34702673 0.61566268 0.67429601
#  0.54587869]
# FAHIM
# [0.78586243 0.79994755 0.83527375 0.41241178 0.643153   0.67186632
#  0.51029072]
# FAHIM
# [0.79775847 0.74688324 0.77888547 0.4079056  0.62340787 0.65779657
#  0.5224657 ]
# FAHIM
# [0.7740486  0.79905254 0.8122074  0.35736749 0.64423873 0.67297704
#  0.53723804]
# FAHIM
# [0.79443572 0.83182387 0.84854278 0.44554323 0.63823474 0.69831524
#  0.55723045]
# FAHIM
# [0.67554179 0.67619092 0.68614673 0.76764667 0.74922517 0.82193259
#  0.75388966]
# [0.64146433 0.70752218 0.69448389 0.77571997 0.76357233 0.82946507
#  0.75691802]
# [0.56233668 0.75777842 0.7125601  0.7360215  0.73911522 0.82472747
#  0.82155624]
# BILL
# [0.52981165 0.73715505 0.70238439 0.67391427 0.76660595 0.79185998
#  0.77865977]
# BILL
# [0.61075643 0.78048074 0.72950466 0.72268832 0.68906733 0.79992364
#  0.7962591 ]
# [0.44025653 0.77846755 0.74429493 0.75326721 0.78701022 0.89039479
#  0.84793495]
# BILL
# [0.63057506 0.76314032 0.73355852 0.74453373 0.75014729 0.83685371
#  0.84751164]
# [0.64085821 0.74908934 0.71412544 0.79673593 0.77477711 0.82062616
#  0.83979983]
# [0.47513072 0.80480118 0.75771297 0.6777056  0.82250492 0.84002713
#  0.81020765]
# BILL
# [0.58781511 0.78793949 0.75850358 0.76219619 0.76374404 0.84753433
#  0.8312524 ]
# BILL
# [0.51898739 0.85505483 0.79643469 0.7843904  0.83816068 0.89606762
#  0.8778618 ]
# BILL
# [0.48750683 0.73975145 0.68625385 0.6834982  0.75001898 0.85503692
#  0.83025621]
# BILL
# [0.38888446 0.76203545 0.72196146 0.7553307  0.79099164 0.87329194
#  0.83796262]
# BILL
# [0.38656972 0.75235474 0.71187429 0.73509106 0.77226253 0.86985376
#  0.81973805]
# BILL
# [0.47620933 0.74852886 0.68891083 0.79850323 0.81668182 0.8921951
#  0.86550696]
# BILL
# [0.77393254 0.84721738 0.87188643 0.30556486 0.66700229 0.70264544
#  0.52949227]
# FAHIM
# [0.77390704 0.83226569 0.84970509 0.3111421  0.63807082 0.67298544
#  0.51570623]
# FAHIM
# [0.77776455 0.79418824 0.80835013 0.31148269 0.63832541 0.66346469
#  0.54293094]
# FAHIM
# [0.78225806 0.81887534 0.83388279 0.29691125 0.61106619 0.68279076
#  0.48879997]
# FAHIM
# [0.79035566 0.83495932 0.83887814 0.33972347 0.62612102 0.69013202
#  0.55525862]
# FAHIM
# [0.7449069  0.78005363 0.81513906 0.35792665 0.62239969 0.67951752
#  0.5671472 ]
# FAHIM
# [0.79998066 0.7779501  0.80252778 0.30640528 0.61897713 0.69245587
#  0.55076072]
# FAHIM
# [0.76442398 0.77972679 0.80508222 0.30811723 0.60678413 0.66103507
#  0.53135581]
# FAHIM
# [0.79663488 0.81818123 0.85107901 0.38545988 0.61638953 0.6508943
#  0.50470653]
# FAHIM
# [0.78617363 0.86494685 0.87572168 0.40312626 0.65761291 0.71146554
#  0.50615558]
# FAHIM
# [0.76645018 0.85516165 0.87288548 0.3465781  0.63971374 0.70057952
#  0.51307886]
# FAHIM
# [0.80180089 0.82778877 0.84852661 0.33750116 0.63272269 0.67036401
#  0.53534266]
# FAHIM
# [0.79000917 0.83489716 0.84975092 0.29994012 0.64290648 0.70997911
#  0.52685876]
# FAHIM
# [0.7957648  0.83184349 0.86155742 0.35051192 0.60477577 0.68420069
#  0.51210642]
# FAHIM
# [0.75541966 0.82832403 0.84514036 0.30680437 0.63732171 0.69341155
#  0.52607527]
# FAHIM
# [0.74962965 0.81343878 0.82611866 0.30851608 0.62953083 0.69526724
#  0.53110344]
# FAHIM
# [0.78167369 0.81377274 0.85186298 0.35284838 0.64413868 0.70207932
#  0.53017501]
# FAHIM
